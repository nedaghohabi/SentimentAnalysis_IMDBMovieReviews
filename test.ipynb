# %%
cv_pth = "./data/IMDB Cleaned.csv"
import pandas as pd
df = pd.read_csv(cv_pth)
review = df['review_cleaned'][0]
review

import nltk
def prepare_sentences(text):
    """Preprocesses text by removing punctuation and tokenizing."""
    # Remove punctuation
    sentences = nltk.sent_tokenize(text)
    sentences = [sent.translate(str.maketrans("", "", string.punctuation)) for sent in sentences]
    sentences = [nltk.word_tokenize(sent) for sent in sentences]
    return sentences

prepare_sentences(review)
# Out:
# [['one',
#   'reviewer',
#   'mentioned',
#   'watching',
#   'a',
#   'of',
#   'episode',
#   'all',
#   'hooked'],
#  ['right',
#   'exactly',
#   'happened',
#   'metre',
#   'first',
#   'thing',
#   'struck',
#   'of',
#   'brutality',
#   'unflinching',
#   'scene',
#   'violence',
#   'set',
#   'right',
#   'word',
#   'go'],
#  ['trust', 'show', 'faint', 'hearted', 'timid'],
#  ['show', 'pull', 'punch', 'regard', 'drug', 'sex', 'violence'],
#  ['hardcore',
#   'classic',
#   'use',
#   'wordit',
#   'called',
#   'of',
#   'nickname',
#   'given',
#   'oswald',
#   'maximum',
#   'security',
#   'state',
#   'penitentiary'],
#  ['focus',
#   'mainly',
#   'emerald',
#   'city',
#   'experimental',
#   'section',
#   'prison',
#   'cell',
#   'glass',
#   'front',
#   'face',
#   'inwards',
#   'privacy',
#   'high',
#   'agenda'],
#  ['pm',
#   'city',
#   'home',
#   'many',
#   'of',
#   'aryan',
#   'muslim',
#   'gangsta',
#   'latino',
#   'christian',
#   'italian',
# ...

# %%
import torch
a = [torch.randn(2) for _ in range(5)]
torch.stack(a)
# Out:
# tensor([[-1.3412,  0.6828],
#         [ 0.7451,  1.3179],
#         [-1.2706, -0.4965],
#         [-1.2044,  0.3033],
#         [-0.0738,  0.5147]])
